# %% [markdown]
# Importação de bibliotecas necessárias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from find_best_hyperparameters import perform_grid_search
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
import string
import os
from model_utils_1 import train_and_evaluate_model
# Out:
# [nltk_data] Downloading package stopwords to /home/hurias/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/hurias/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Dados - review_polarity.csv

# %%
# Define o caminho do corpus (pode ser alterado no notebook)
corpus_path = "/home/hurias/Documentos/Disciplina_NLP/Atv_3/data/review_polarity.csv"

# %%
df = pd.read_csv(corpus_path)
df
# Out:
#             file_name                                               text class
# 0     cv145_12239.txt  it was once said that in order to truly enjoy ...   neg
# 1     cv745_14009.txt  conventional wisdom among collectibles retaile...   neg
# 2     cv376_20883.txt  robin williams has the rarest of gifts : the a...   neg
# 3     cv109_22599.txt  nearly every film tim burton has directed has ...   neg
# 4     cv494_18689.txt  you know , i never really wondered what the ta...   neg
# ...               ...                                                ...   ...
# 1995   cv964_6021.txt  you've got to think twice before you go see a ...   pos
# 1996  cv989_15824.txt  lisa cholodenko's " high art , " is an intelli...   pos
# 1997  cv355_16413.txt  to paraphrase a song title from an earlier dis...   pos
# 1998  cv463_10343.txt  one fun activity for parents during the holida...   pos
# 1999  cv265_10814.txt  one way of telling if a film is good or not is...   pos
#
# [2000 rows x 3 columns]

# %%
train_and_evaluate_model(
    corpus_path="/home/hurias/Documentos/Disciplina_NLP/Atv_3/data/review_polarity.csv", 
    model_name="MultinomialNB", 
    perform_grid_search_flag=True, 
    results_file="MultinomialNB_grid_results.csv"
)
# Out:
# Treinando e avaliando o modelo com a base: /home/hurias/Documentos/Disciplina_NLP/Atv_3/data/review_polarity.csv
#
# Processando o arquivo: MultinomialNB_grid_results.csv
#             params  mean_test_score  rank_test_score
# 0   {'alpha': 0.1}         0.845000                1
# 1   {'alpha': 0.2}         0.844375                2
# 2   {'alpha': 0.5}         0.831250                3
# 3  {'alpha': 0.75}         0.827500                4
# 4     {'alpha': 1}         0.821250                5
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#          neg       0.80      0.76      0.78       200
#          pos       0.77      0.81      0.79       200
#
#     accuracy                           0.79       400
#    macro avg       0.79      0.78      0.78       400
# weighted avg       0.79      0.79      0.78       400

# %%
train_and_evaluate_model(
    corpus_path="/home/hurias/Documentos/Disciplina_NLP/Atv_3/data/review_polarity.csv", 
    model_name="LogisticRegression", 
    perform_grid_search_flag=True, 
    results_file="LogisticRegression_grid_results.csv"
)
# Out:
# Treinando e avaliando o modelo com a base: /home/hurias/Documentos/Disciplina_NLP/Atv_3/data/review_polarity.csv
#
# Processando o arquivo: LogisticRegression_grid_results.csv
#                                                params  mean_test_score  \
# 13  {'C': 1, 'penalty': 'l2', 'solver': 'liblinear...         0.797500
# 14  {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs', '...         0.797500
# 12  {'C': 1, 'penalty': 'l2', 'solver': 'liblinear...         0.796875
# 9   {'C': 1, 'penalty': 'l1', 'solver': 'liblinear...         0.663125
# 8   {'C': 1, 'penalty': 'l1', 'solver': 'liblinear...         0.660000
#
#     rank_test_score
# 13                1
# 14                1
# 12                3
# 9                 4
# 8                 5
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#          neg       0.79      0.78      0.78       200
#          pos       0.78      0.79      0.78       200
#
# ...

# %% [markdown]
# # Dados - SyskillWebert.csv

# %%
from model_utils_2 import train_and_evaluate_model

# %%
corpus_path = "/home/hurias/Documentos/Disciplina_NLP/Atv_3/data/review_polarity.csv"

# %%
train_and_evaluate_model(
    corpus_path= "/home/hurias/Documentos/Disciplina_NLP/Atv_3/data/SyskillWebert.csv",
    model_name="MultinomialNB", 
    perform_grid_search_flag=True, 
    results_file="MultinomialNB_grid_results.csv"
)
# Out:
# Treinando e avaliando o modelo com a base: /home/hurias/Documentos/Disciplina_NLP/Atv_3/data/SyskillWebert.csv
#
# Processando o arquivo: MultinomialNB_grid_results.csv
#             params  mean_test_score  rank_test_score
# 0   {'alpha': 0.1}         0.838994                1
# 1   {'alpha': 0.2}         0.790217                2
# 2   {'alpha': 0.5}         0.674144                3
# 3  {'alpha': 0.75}         0.603284                4
# 4     {'alpha': 1}         0.517121                5
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#        Bands       0.92      1.00      0.96        12
#   BioMedical       0.76      1.00      0.86        28
#        Goats       0.88      0.50      0.64        14
#        Sheep       1.00      0.69      0.82        13
#
#     accuracy                           0.84        67
#    macro avg       0.89      0.80      0.82        67
# weighted avg       0.86      0.84      0.82        67

# %%
train_and_evaluate_model(
    corpus_path="/home/hurias/Documentos/Disciplina_NLP/Atv_3/data/SyskillWebert.csv", 
    model_name="LogisticRegression", 
    perform_grid_search_flag=True, 
    results_file="LogisticRegression_grid_results.csv"
)
# Out:
# Treinando e avaliando o modelo com a base: /home/hurias/Documentos/Disciplina_NLP/Atv_3/data/SyskillWebert.csv
#
# Processando o arquivo: LogisticRegression_grid_results.csv
#                                                params  mean_test_score  \
# 9   {'C': 1, 'penalty': 'l1', 'solver': 'liblinear...         0.850175
# 8   {'C': 1, 'penalty': 'l1', 'solver': 'liblinear...         0.839203
# 13  {'C': 1, 'penalty': 'l2', 'solver': 'liblinear...         0.838714
# 14  {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs', '...         0.835150
# 12  {'C': 1, 'penalty': 'l2', 'solver': 'liblinear...         0.779036
#
#     rank_test_score
# 9                 1
# 8                 2
# 13                3
# 14                4
# 12                5
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#        Bands       1.00      0.17      0.29        12
#   BioMedical       0.70      1.00      0.82        28
# ...
